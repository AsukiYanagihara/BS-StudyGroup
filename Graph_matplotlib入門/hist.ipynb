# %%
# conding: utf-8

# %%
"""
ヒストグラム・100*100行列の可視化
"""

# %%
# モジュールのインポート
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.hist(np.random.randn(1000)) #ヒストグラム
# Out:
# (array([ 11.,  49., 130., 264., 267., 194.,  75.,   9.,   0.,   1.]),
#  array([-3.08762509, -2.3407556 , -1.59388611, -0.84701662, -0.10014714,
#          0.64672235,  1.39359184,  2.14046132,  2.88733081,  3.6342003 ,
#          4.38106979]),
#  <a list of 10 Patch objects>)

# %%
plt.imshow(np.random.randn(100,100)) #100*100行列の可視化

# %%
#グラフにタイトルをつける
plt.imshow(np.random.randn(100,100))
plt.title("100*100 matrix")
# Out:
# Text(0.5,1,'100*100 matrix')
